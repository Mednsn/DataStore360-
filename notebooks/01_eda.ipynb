# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


df = pd.read_csv("../data/raw/dataset.csv")

# print(df.head())
# print(df.shape)
# print(df.columns)
# print(df.dtypes)
# print(df.isna().sum())
# print(df.duplicated().sum())
# print(df.describe())

# df["Sales"].hist(bins=30)

# plt.title("Distribution des ventes")
# plt.xlabel("Sales")
# plt.ylabel("Nombre")
# plt.show()

invalid_discount = df[df["Discount"] > 1]

print(invalid_discount)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 3096    3097  CA-2015-114468   8/23/2015   8/23/2015        Same Day
# 3501    3502  CA-2016-108616   9/29/2016   10/3/2016  Standard Class
# 4551    4552  US-2014-165862   7/13/2014   7/17/2014             NaN
# 4710    4711  CA-2017-138149   6/29/2017   6/30/2017     First Class
# 6405    6406  CA-2017-154074   8/31/2017    9/2/2017    Second Class
# 6457    6458  CA-2014-110065    8/5/2014   8/11/2014  Standard Class
# 6683    6684  CA-2014-109134   11/5/2014  11/10/2014  Standard Class
# 8814    8815  CA-2015-144274  11/23/2015  11/25/2015    Second Class
# 9291    9292  CA-2014-163650   9/23/2014   9/25/2014     First Class
# 9352    9353  CA-2017-148411   9/24/2017   9/26/2017     First Class
#
#      Customer ID     Customer Name      Segment        Country           City  \
# 3096    TD-20995     Tamara Dahlen     Consumer  United States    Bolingbrook
# 3501    JK-15730     Joe Kamberova     Consumer  United States         Mobile
# 4551    GK-14620       Grace Kelly    Corporate  United States    Los Angeles
# 4710    WB-21850     William Brown     Consumer  United States    Los Angeles
# 6405    BW-11110      Bart Watters    Corporate  United States        Spokane
# 6457    SP-20650  Stephanie Phelps    Corporate  United States  New York City
# 6683    DE-13255        Deanra Eno  Home Office  United States    Los Angeles
# 8814    PW-19240      Pierre Wener     Consumer  United States     Wilmington
# 9291    TT-21220   Thomas Thornton     Consumer  United States          Dover
# 9352    RO-19780               NaN     Consumer  United States        Chicago
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# 3096  ...     60440.0  Central  OFF-AP-10000696  Office Supplies   Appliances
# 3501  ...     36608.0    South  OFF-AR-10001149  Office Supplies          Art
# 4551  ...     90049.0     West  FUR-TA-10002855        Furniture       Tables
# 4710  ...     90049.0     West  TEC-AC-10001284       Technology  Accessories
# 6405  ...     99207.0     West  FUR-CH-10002331        Furniture       Chairs
# 6457  ...     10009.0     East  OFF-AR-10004165  Office Supplies          Art
# 6683  ...     90008.0     West  FUR-FU-10000320        Furniture  Furnishings
# 8814  ...     19805.0     East  TEC-PH-10003012       Technology       Phones
# 9291  ...     19901.0     East  OFF-BI-10004965  Office Supplies      Binders
# 9352  ...     60623.0  Central  FUR-CH-10003973        furniture       Chairs
#
#                                            Product Name    Sales  Quantity  \
# 3096                                Holmes Odor Grabber    5.768       2.0
# 3501          Sanford Colorific Colored Pencils, 12/Box   25.920       9.0
# 4551  Bevis Round Conference Table Top & Single Colu...  351.216       3.0
# 4710  Enermax Briskie RF Wireless Keyboard and Mouse...   62.310       3.0
# 6405  Hon 4700 Series Mobuis Mid-Back Task Chairs wi...  569.568       2.0
# 6457  Binney & Smith inkTank Erasable Pocket Highlig...   15.960       7.0
# 6683                                 OIC Stacking Trays   20.040       6.0
# 8814   Nortel Meridian M3904 Professional Digital phone  307.980       2.0
# 9291  Ibico Covers for Plastic or Wire Binding Elements   34.500       3.0
# 9352         GuestStacker Chair with Chrome Finish Legs  520.464       2.0
#
#       Discount   Profit
# 3096       1.5 -13.5548
# 3501       1.5   7.7760
# 4551       1.5   4.3902
# 4710       1.5  22.4316
# 6405       1.5   7.1196
# 6457       1.5   7.0224
# 6683       1.5   8.8176
# 8814       1.5  89.3142
# 9291       1.5  15.5250
# 9352       1.5 -14.8704
#
# [10 rows x 21 columns]
